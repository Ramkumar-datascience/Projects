# %%
# API KEY - 764f244ba6b9b1fcafbfe91ae7e9601c
# eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NjRmMjQ0YmE2YjliMWZjYWZiZmU5MWFlN2U5NjAxYyIsIm5iZiI6MTc0NjUzNDU0MC41Niwic3ViIjoiNjgxYTAwOGM3YTAzMTk2MDQxNzRiNjQ5Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.NXwXVDc8fG89gaVplhg_RZwvLag2g9XXWBkoOQra0GI

# %%
# Account details
username : RamkumarTMDB
password : Ramkumar@123

# creating API Key
click on profile --> API Subscription --> API

# Getting Headers
click on profile --> More --> API Documentation --> API Reference -->Authentication --> Select Python in the right side --> Copy code

# %% [markdown]
# # Top rated movies list

# %%
import requests

url = "https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=10"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NjRmMjQ0YmE2YjliMWZjYWZiZmU5MWFlN2U5NjAxYyIsIm5iZiI6MTc0NjUzNDU0MC41Niwic3ViIjoiNjgxYTAwOGM3YTAzMTk2MDQxNzRiNjQ5Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.NXwXVDc8fG89gaVplhg_RZwvLag2g9XXWBkoOQra0GI"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":10,"results":[{"adult":false,"backdrop_path":"/9UolwLE0kfN4orxKwXdevJPWjNI.jpg","genre_ids":[16,35],"id":86836,"origin_country":["JP"],"original_language":"ja","original_name":"なんでここに先生が!?","overview":"Ichiro Sato is about as average as a student can get... except for his above-average ability to land himself in totally awkward, intensely risqué situations with his no-nonsense teacher, Kana Kojima! Ichiro has his hands full dealing with these steamy shenanigans and unexpected encounters in the most unlikely places. At least it can’t get any worse, right?","popularity":7.5898,"poster_path":"/mhHtZNOPSnW9RyQH9f8S313EYng.jpg","first_air_date":"2019-04-08","name":"Why the Hell Are You Here, Teacher!?","vote_average":8.461,"vote_count":670},{"adult":false,"backdrop_path":"/c2sl2dLlyFFeb18pJtOpBD8cidr.jpg","genre_ids":[16],"id":72517,"origin_country":["JP"],"original_language":"ja","original_name":"ようこそ実力至上主義の教室へ","overview":"Kiyotaka Ayanokoji has just enrolled at Tokyo Koudo Ikus
# ...

# %%
data = response.text

# %%
import json

# %%
data = json.loads(data)

# %%
data.keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
data['page']
# Out:
# 1

# %%
len(data['total_pages'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-f2aba0c46b94> in <module>
# ----> 1 len(data['total_pages'])
#
# TypeError: object of type 'int' has no len()

# %%
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/9faGSFi5jam6pDWGNd0p8JcJgXQ.jpg',
#    'genre_ids': [18, 80],
#    'id': 1396,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Breaking Bad',
#    'overview': "Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live. He becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.",
#    'popularity': 122.9559,
#    'poster_path': '/ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg',
#    'first_air_date': '2008-01-20',
#    'name': 'Breaking Bad',
#    'vote_average': 8.926,
#    'vote_count': 15523},
#   {'adult': False,
#    'backdrop_path': '/5yk3QwnQxzwKfhU1tlDkV2PSIBz.jpg',
#    'genre_ids': [18],
#    'id': 219246,
#    'origin_country': ['KR'],
#    'original_language': 'ko',
# ...

# %%
pd.DataFrame(data['results']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              20 non-null     bool
#  1   backdrop_path      20 non-null     object
#  2   genre_ids          20 non-null     object
#  3   id                 20 non-null     int64
#  4   origin_country     20 non-null     object
#  5   original_language  20 non-null     object
#  6   original_name      20 non-null     object
#  7   overview           20 non-null     object
#  8   popularity         20 non-null     float64
#  9   poster_path        20 non-null     object
#  10  first_air_date     20 non-null     object
#  11  name               20 non-null     object
#  12  vote_average       20 non-null     float64
#  13  vote_count         20 non-null     int64
# dtypes: bool(1), float64(2), int64(2), object(9)
# memory usage: 2.2+ KB

# %%
df = pd.DataFrame(data['results'])[['id','original_language',"origin_country","first_air_date","vote_average","name","vote_count"]]
# Out:
#         id original_language origin_country first_air_date  vote_average  \
# 0    86836                ja           [JP]     2019-04-08         8.461
# 1    72517                ja           [JP]     2017-07-12         8.461
# 2    82684                ja           [JP]     2018-10-02         8.500
# 3     4194                en           [US]     2008-10-03         8.459
# 4    76479                en           [US]     2019-07-25         8.458
# 5    62273                ja           [JP]     2015-04-04         8.457
# 6     1399                en           [US]     2011-04-17         8.457
# 7    66078                ja           [JP]     2016-04-06         8.500
# 8   111819                ja           [JP]     2021-07-07         8.455
# 9   136283                ko           [KR]     2022-12-30         8.454
# 10   35753                ja           [JP]     2006-07-03         8.500
# 11    2723                en           [US]     2001-08-10         8.500
# ...

# %%
# Mapping of genre IDs to genre names
genre_mapping = {
    18: "Drama",
    80: "Crime",
    16: "Animation",
    10759: "Action & Adventure",
    10765: "Sci-Fi & Fantasy",
    35: "Comedy"
}

# %%
data['total_results']
# Out:
# 2192

# %%
df = pd.DataFrame()
for i in range(1, 110):
    url = "https://api.themoviedb.org/3/tv/top_rated?language=en-US&page="+str(i)
    print(url)
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NjRmMjQ0YmE2YjliMWZjYWZiZmU5MWFlN2U5NjAxYyIsIm5iZiI6MTc0NjUzNDU0MC41Niwic3ViIjoiNjgxYTAwOGM3YTAzMTk2MDQxNzRiNjQ5Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.NXwXVDc8fG89gaVplhg_RZwvLag2g9XXWBkoOQra0GI"
    }

    response = requests.get(url, headers=headers)
    data = response.text
    data = json.loads(data)
    df1 = pd.DataFrame(data['results'])[['id','original_language',"origin_country","first_air_date","vote_average","name","vote_count"]]
    df = df.append(df1,ignore_index=True)
# Out:
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=1
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=2
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=3
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=4
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=5
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=6
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=7
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=8
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=9
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=10
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=11
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=12
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=13
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=14
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=15
# ...

# %%
df
# Out:
#           id original_language origin_country first_air_date  vote_average  \
# 0       1396                en           [US]     2008-01-20         8.926
# 1     219246                ko           [KR]     2025-03-07         8.876
# 2     209867                ja           [JP]     2023-09-29         8.800
# 3      94605                en           [US]     2021-11-06         8.776
# 4     131378                en           [US]     2023-08-31         8.763
# ...      ...               ...            ...            ...           ...
# 2175    4419                en           [US]     2003-02-21         6.000
# 2176    4386                en           [US]     1989-04-23         5.943
# 2177   37678                en           [US]     2011-04-26         5.925
# 2178   68716                en           [US]     2017-09-29         5.914
# 2179   68295                en       [GB, US]     2016-10-01         5.900
#
#                                 name  vote_count
# ...

# %%
#df.to_csv("./TMBD with API/top_rated.csv")

# %% [markdown]
# # Upcoming movies list

# %%
import requests

url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NjRmMjQ0YmE2YjliMWZjYWZiZmU5MWFlN2U5NjAxYyIsIm5iZiI6MTc0NjUzNDU0MC41Niwic3ViIjoiNjgxYTAwOGM3YTAzMTk2MDQxNzRiNjQ5Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.NXwXVDc8fG89gaVplhg_RZwvLag2g9XXWBkoOQra0GI"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"dates":{"maximum":"2025-06-11","minimum":"2025-05-21"},"page":1,"results":[{"adult":false,"backdrop_path":"/jRvhP4AfFnJ03lCQhp1fie7XPSd.jpg","genre_ids":[28,53],"id":977294,"original_language":"en","original_title":"Tin Soldier","overview":"An ex-special forces operative seeks revenge against a cult leader who has corrupted his former comrades, the Shinjas. This leader, known as The Bokushi, promises veterans a purpose and protection, but is revealed to be a destructive influence. The ex-soldier, Nash Cavanaugh, joins forces with military operative Emmanuel Ashburn to infiltrate the Bokushi's fortress and expose his reign of terror","popularity":394.0376,"poster_path":"/lFFDrFLXywFhy6khHes1LCFVMsL.jpg","release_date":"2025-05-22","title":"Tin Soldier","video":false,"vote_average":6.0,"vote_count":1},{"adult":false,"backdrop_path":"/j0NUh5irX7q2jIRtbLo8TZyRn6y.jpg","genre_ids":[27,9648],"id":574475,"original_language":"en","original_title":"Final Destination Bloodlines","overview":"
# ...

# %%
data = json.loads(response.text)

# %%
data.keys()
# Out:
# dict_keys(['dates', 'page', 'results', 'total_pages', 'total_results'])

# %%
data['total_pages']
# Out:
# 51

# %%
data['total_results']
# Out:
# 1005

# %%
upcoming_movies_df = pd.DataFrame()
for i in range(1, 51):
    url = "https://api.themoviedb.org/3/tv/top_rated?language=en-US&page="+str(i)
    print(url)
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NjRmMjQ0YmE2YjliMWZjYWZiZmU5MWFlN2U5NjAxYyIsIm5iZiI6MTc0NjUzNDU0MC41Niwic3ViIjoiNjgxYTAwOGM3YTAzMTk2MDQxNzRiNjQ5Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.NXwXVDc8fG89gaVplhg_RZwvLag2g9XXWBkoOQra0GI"
    }

    response = requests.get(url, headers=headers)
    data = response.text
    data = json.loads(data)
    df1 = pd.DataFrame(data['results'])[['id','original_language',"origin_country","first_air_date","vote_average","name","vote_count"]]
    upcoming_movies_df = upcoming_movies_df.append(df1,ignore_index=True)
# Out:
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=1
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=2
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=3
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=4
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=5
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=6
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=7
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=8
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=9
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=10
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=11
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=12
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=13
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=14
# https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=15
# ...

# %%
upcoming_movies_df
# Out:
#          id original_language origin_country first_air_date  vote_average  \
# 0      1396                en           [US]     2008-01-20         8.926
# 1    219246                ko           [KR]     2025-03-07         8.876
# 2    209867                ja           [JP]     2023-09-29         8.800
# 3     94605                en           [US]     2021-11-06         8.776
# 4    131378                en           [US]     2023-08-31         8.763
# ..      ...               ...            ...            ...           ...
# 995    1660                en           [US]     1965-09-18         7.800
# 996   78204                ja           [JP]     2018-04-08         7.826
# 997   54671                en           [US]     2014-05-11         7.825
# 998   35279                en           [US]     2011-12-02         7.825
# 999   54583                es             []     2010-09-20         7.824
#
#                                               name  vote_count
# ...

# %%
df.iloc[998]
# Out:
# id                           35279
# original_language               en
# origin_country                [US]
# first_air_date          2011-12-02
# vote_average                 7.825
# name                 Austin & Ally
# vote_count                     204
# Name: 998, dtype: object

# %%
import requests

url = "https://api.themoviedb.org/3/certification/movie/list"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NjRmMjQ0YmE2YjliMWZjYWZiZmU5MWFlN2U5NjAxYyIsIm5iZiI6MTc0NjUzNDU0MC41Niwic3ViIjoiNjgxYTAwOGM3YTAzMTk2MDQxNzRiNjQ5Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.NXwXVDc8fG89gaVplhg_RZwvLag2g9XXWBkoOQra0GI"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"certifications":{"BR":[{"certification":"14","meaning":"Not recommended for minors under fourteen. More violent material, stronger sex references and/or nudity.","order":4},{"certification":"16","meaning":"Not recommended for minors under sixteen. Scenes featuring production, trafficking and/or use of illegal drugs, hyper-realistic sex, sexual violence, abortion, torture, mutilation, suicide, trivialization of violence and death penalty.","order":5},{"certification":"L","meaning":"General Audiences. Do not expose children to potentially harmful content.","order":1},{"certification":"12","meaning":"Not recommended for minors under twelve. Scenes can include physical aggression, use of legal drugs and sexual innuendo.","order":3},{"certification":"10","meaning":"Not recommended for minors under ten. Violent content or inappropriate language to children, even if of a less intensity.","order":2},{"certification":"18","meaning":"Not recommended for minors under eighteen. Scenes featurin
# ...

# %%
data = json.loads(response.text)

# %%
data.keys()
# Out:
# dict_keys(['certifications'])

# %%
data['certifications'].keys()
# Out:
# dict_keys(['BR', 'BG', 'DE', 'DK', 'ES', 'FR', 'NZ', 'CA', 'CA-QC', 'FI', 'GB', 'US', 'TH', 'MX', 'HU', 'LT', 'MY', 'NO', 'PT', 'AU', 'NL', 'RU', 'SE', 'SK', 'IN', 'IT', 'PH', 'KR', 'ID', 'PR', 'AT', 'LV', 'AR', 'SG', 'ZA', 'GR', 'CH', 'UA', 'PL', 'CL', 'IE', 'HK', 'TR', 'JP', 'MO', 'IL', 'LU', 'VI', 'CZ', 'TW', 'RO', 'BE'])

# %%
data['certifications']['BG']
# Out:
# [{'certification': 'D',
#   'meaning': 'Prohibited for persons under 16.',
#   'order': 4},
#  {'certification': 'X',
#   'meaning': 'Prohibited for persons under 18.',
#   'order': 5},
#  {'certification': 'B', 'meaning': 'Without age restrictions.', 'order': 2},
#  {'certification': 'C',
#   'meaning': 'Not recommended for children under 12.',
#   'order': 3},
#  {'certification': 'A', 'meaning': 'Recommended for children.', 'order': 1}]

# %%
pd.DataFrame(data['certifications']['CZ'])
# Out:
#   certification                                      meaning  order
# 0            UR                                   Not rated.      0
# 1             U                                No age limit.      1
# 2           12+  Unsuitable for persons under the age of 12.      2
# 3           15+  Unsuitable for persons under the age of 15.      3
# 4           18+  Unsuitable for persons under the age of 18.      4
